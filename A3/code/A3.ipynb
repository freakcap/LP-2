# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Data Preprocessing
dataset = pd.read_csv('data.csv', header = None)
transactions = []
for i in range(0, 4):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 7)])


# Training Apriori on the dataset
# !pip install apyori
from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# Visualising the results
results = list(rules)

print("Number of rules mined = " + str(len(results)))

for item in results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=432ff1e2c5931fa0b5f2acabadc7e93f1d1df6894edaf8158c2b9766facbc43a
#   Stored in directory: /home/freakcap/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2
# Number of rules mined = 79
# Rule: k -> i
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: k -> i
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> b
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: i -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: nan -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: k -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> f
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> g
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> g
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: i -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: i -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: k -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> f
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: k -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> f
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: nan -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: nan -> f
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: i -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: c -> f
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> k
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: nan -> f
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: a -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> b
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> b
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: b -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> c
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> b
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: nan -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: e -> a
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> b
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> nan
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
# Rule: d -> e
# Support: 0.25
# Confidence: 1.0
# Lift: 4.0
# =====================================
